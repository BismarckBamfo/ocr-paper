# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.insert(0, '/content/drive/MyDrive/trainer')

# %%
# %cd /content/drive/MyDrive/trainer
import os
import torch.backends.cudnn as cudnn
import yaml
from train import train
from utils import AttrDict
import pandas as pd
# Out:
# /content/drive/MyDrive/trainer

# %%
cudnn.benchmark = True
cudnn.deterministic = False

# %%
def get_config(file_path):
    with open(file_path, 'r', encoding="utf8") as stream:
        opt = yaml.safe_load(stream)
    opt = AttrDict(opt)
    if opt.lang_char == 'None':
        characters = ''
        for data in opt['select_data'].split('-'):
            csv_path = os.path.join(opt['train_data'], data, 'labels.csv')
            df = pd.read_csv(csv_path, sep='^([^,]+),', engine='python', usecols=['filename', 'words'], keep_default_na=False)
            all_char = ''.join(df['words'])
            characters += ''.join(set(all_char))
        characters = sorted(set(characters))
        opt.character= ''.join(characters)
    else:
        opt.character = opt.number + opt.symbol + opt.lang_char
    os.makedirs(f'./saved_models/{opt.experiment_name}', exist_ok=True)
    return opt

# %%
opt = get_config("/content/tw_filtered_config.yaml")
train(opt, amp=False)
# Out:
# {'number': '0123456789', 'symbol': '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ €', 'lang_char': 'ABƆDEFGHIƐKLMNOPQRSTUVWXYZabɔdefghiɛklmnopqrstuvwxyz', 'experiment_name': 'tw_filtered', 'train_data': 'all_data', 'valid_data': 'all_data/tw_val', 'manualSeed': 1111, 'workers': 6, 'batch_size': 32, 'num_iter': 300000, 'valInterval': 20000, 'saved_model': '', 'FT': False, 'optim': False, 'lr': 1.0, 'beta1': 0.9, 'rho': 0.95, 'eps': 1e-08, 'grad_clip': 5, 'select_data': 'train', 'batch_ratio': '1', 'total_data_usage_ratio': 1.0, 'batch_max_length': 34, 'imgH': 64, 'imgW': 600, 'rgb': False, 'contrast_adjust': 0.0, 'sensitive': True, 'PAD': True, 'data_filtering_off': False, 'Transformation': 'None', 'FeatureExtraction': 'VGG', 'SequenceModeling': 'BiLSTM', 'Prediction': 'CTC', 'num_fiducial': 20, 'input_channel': 1, 'output_channel': 256, 'hidden_size': 256, 'decode': 'greedy', 'new_prediction': False, 'freeze_FeatureFxtraction': False, 'freeze_SequenceModeling': False, 'character': '0123456789!"
# ...

# %%
# !unzip "/content/drive/MyDrive/data/try_data.zip" -d "/content/drive/MyDrive/data/"

# %%
# !cp -r /content/drive/MyDrive/trainer /content
# Out:
# cp: cannot access '/content/drive/MyDrive/trainer/all_data/train': Input/output error

# %%
# !zip -r "/content/drive/MyDrive/ocr_trainer.zip" "/content/drive/MyDrive/trainer"

# %%
# !pip install wandb
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 4.6 MB/s
# ...
#      |████████████████████████████████| 140 kB 45.9 MB/s
# ...
#      |████████████████████████████████| 97 kB 6.7 MB/s
# ...
#      |████████████████████████████████| 180 kB 48.1 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.8 MB/s
# ...
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6502 sha256=dbfa148df51f482702473138cd35a53f977ceea9354e1ff2ce003c33fab0d9d1
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8807 sha256=f4f298682d488e37c8cc77c7a4584e66b07576e427ffba3ac9ad4b73975071b9
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built subprocess32 pathtools
# ...

# %%
# %cd /content/drive/MyDrive/trainer
# !python /content/drive/MyDrive/trainer/train.py
# Out:
# /content/drive/MyDrive/trainer
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.12.9
# wandb: Syncing run cerulean-firebrand-10
# wandb: ⭐️ View project at https://wandb.ai/bismarckbamfo91/ocr-paper
# wandb: 🚀 View run at https://wandb.ai/bismarckbamfo91/ocr-paper/runs/1y19k6ss
# wandb: Run data is saved locally in /content/drive/My Drive/trainer/wandb/run-20211227_214110-1y19k6ss
# wandb: Run `wandb offline` to turn off syncing.
#
# Filtering the images containing characters which are not in opt.character
# ...

# %%
# Out:
# /content/drive/MyDrive/trainer
